# %%
import pandas as pd

# %%
df = pd.read_csv("SpotifyFeatures.csv")
df
# Out:
#         genre               artist_name                        track_name  \
# 0       Movie            Henri Salvador       C'est beau de faire un Show
# 1       Movie         Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2       Movie           Joseph Williams    Don't Let Me Be Lonely Tonight
# 3       Movie            Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Movie              Fabien Nataf                         Ouverture
# ...       ...                       ...                               ...
# 232720   Soul                     Slave                      Son Of Slide
# 232721   Soul  Jr Thomas & The Volcanos                      Burning Fire
# 232722   Soul              Muddy Waters    (I'm Your) Hoochie Coochie Man
# 232723   Soul                   R.LUM.R                     With My Words
# 232724   Soul            Mint Condition    You Don't Have To Hurt No More
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
spotify_df.isnull()
# Out:
#         acousticness  danceability  energy  instrumentalness  liveness  \
# 0              False         False   False             False     False
# 1              False         False   False             False     False
# 2              False         False   False             False     False
# 3              False         False   False             False     False
# 4              False         False   False             False     False
# ...              ...           ...     ...               ...       ...
# 232720         False         False   False             False     False
# 232721         False         False   False             False     False
# 232722         False         False   False             False     False
# 232723         False         False   False             False     False
# 232724         False         False   False             False     False
#
#         loudness  speechiness  tempo  valence
# 0          False        False  False    False
# ...

# %%
spotify_df
# Out:
#         acousticness  danceability  energy  instrumentalness  liveness  \
# 0            0.61100         0.389   0.910          0.000000    0.3460
# 1            0.24600         0.590   0.737          0.000000    0.1510
# 2            0.95200         0.663   0.131          0.000000    0.1030
# 3            0.70300         0.240   0.326          0.000000    0.0985
# 4            0.95000         0.331   0.225          0.123000    0.2020
# ...              ...           ...     ...               ...       ...
# 232720       0.00384         0.687   0.714          0.544000    0.0845
# 232721       0.03290         0.785   0.683          0.000880    0.2370
# 232722       0.90100         0.517   0.419          0.000000    0.0945
# 232723       0.26200         0.745   0.704          0.000000    0.3330
# 232724       0.09730         0.758   0.470          0.000049    0.0836
#
#         loudness  speechiness    tempo  valence
# 0         -1.828       0.0525  166.969    0.814
# ...

# %%
import numpy as np
# import pandas as pd
# from pandas_profiling import ProfileReport
# df.valu
df.nunique()
# Out:
# genre                   27
# artist_name          14564
# track_name          148615
# track_id            176774
# popularity             101
# acousticness          4734
# danceability          1295
# duration_ms          70749
# energy                2517
# instrumentalness      5400
# key                     12
# liveness              1732
# loudness             27923
# mode                     2
# speechiness           1641
# tempo                78512
# time_signature           5
# valence               1692
# dtype: int64

# %%
df.describe(include="all")
# df["genre"].unique()
# Out:
#          genre     artist_name track_name                track_id  \
# count   232725          232725     232725                  232725
# unique      27           14564     148615                  176774
# top     Comedy  Giuseppe Verdi       Home  3uSSjnDMmoyERaAK9KvpJR
# freq      9681            1394        100                       8
# mean       NaN             NaN        NaN                     NaN
# std        NaN             NaN        NaN                     NaN
# min        NaN             NaN        NaN                     NaN
# 25%        NaN             NaN        NaN                     NaN
# 50%        NaN             NaN        NaN                     NaN
# 75%        NaN             NaN        NaN                     NaN
# max        NaN             NaN        NaN                     NaN
#
#            popularity   acousticness   danceability   duration_ms  \
# count   232725.000000  232725.000000  232725.000000  2.327250e+05
# ...

# %%
df.nunique()
# Out:
# genre                   27
# artist_name          14564
# track_name          148615
# track_id            176774
# popularity             101
# acousticness          4734
# danceability          1295
# duration_ms          70749
# energy                2517
# instrumentalness      5400
# key                     12
# liveness              1732
# loudness             27923
# mode                     2
# speechiness           1641
# tempo                78512
# time_signature           5
# valence               1692
# dtype: int64

# %%
df["mode"].unique()
# Out:
# array(['Major', 'Minor'], dtype=object)

# %%
important_features = [
#     "genre",  # spotify genre doesn't match with kaggle genre
#     "popularity",  # don't know how to get it for the song, and it changes over time
#     "key",  # This is categorical
#     "mode",  # this is categorical
#     "time_signature"  # not for now
    
    "acousticness",
    "danceability",
    "energy",
    "instrumentalness",
    "liveness",
    "loudness",
    "speechiness",
    "tempo",
    "valence",
]

# df[important_features]["time_signature"].unique()
spotify_df = df[important_features]

# %%
spotify_df.dtypes
# Out:
# acousticness        float64
# danceability        float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# tempo               float64
# valence             float64
# dtype: object

# %%
# df[important_features]["time_signature"].hist()

# %%
# from sklearn.preprocessing import OrdinalEncoder

# %%
# encoder = OrdinalEncoder()
# categorical_columns = [
#     "key",
#     "mode"
# ]
# spotify_df.loc[:, categorical_columns] = encoder.fit_transform(spotify_df[categorical_columns])

# %%
spotify_df
# Out:
#         acousticness  danceability  energy  instrumentalness  liveness  \
# 0            0.61100         0.389   0.910          0.000000    0.3460
# 1            0.24600         0.590   0.737          0.000000    0.1510
# 2            0.95200         0.663   0.131          0.000000    0.1030
# 3            0.70300         0.240   0.326          0.000000    0.0985
# 4            0.95000         0.331   0.225          0.123000    0.2020
# ...              ...           ...     ...               ...       ...
# 232720       0.00384         0.687   0.714          0.544000    0.0845
# 232721       0.03290         0.785   0.683          0.000880    0.2370
# 232722       0.90100         0.517   0.419          0.000000    0.0945
# 232723       0.26200         0.745   0.704          0.000000    0.3330
# 232724       0.09730         0.758   0.470          0.000049    0.0836
#
#         loudness  speechiness    tempo  valence
# 0         -1.828       0.0525  166.969    0.814
# ...

# %%
# from seaborn import pairplot
# pairplot(spotify_df)
X = spotify_df

# %%
from sklearn.cluster import KMeans 
kmeans = KMeans(n_clusters=10000)
kmeans.fit(X)
labels = kmeans.labels_

# print(labels)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-9c1c931337fb> in <module>
#       1 from sklearn.cluster import KMeans
#       2 kmeans = KMeans(n_clusters=10000)
# ----> 3 kmeans.fit(X)
#       4 labels = kmeans.labels_
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     935                     max_iter=self.max_iter, init=init, verbose=self.verbose,
#     936                     precompute_distances=precompute_distances, tol=tol,
# --> 937                     x_squared_norms=x_squared_norms, random_state=seed)
#     938                 # determine if these results are the best so far
#     939                 if best_inertia is None or inertia < best_inertia:
#
# ...

# %%
# from sklearn.preprocessing import Ca

# %%
def spotify_data_cleaner(kaggle_dataset):
    #     1. keeping important features
    important_features = [
    #     "genre",  # spotify genre doesn't match with kaggle genre
    #     "popularity",  # don't know how to get it for the song, and it changes over time
    #     "key",  # This is categorical
    #     "mode",  # this is categorical
    #     "time_signature"  # not for now
    "acousticness",
    "danceability",
    "energy",
    "instrumentalness",
    "liveness",
    "loudness",
    "speechiness",
    "tempo",
    "valence",
]
